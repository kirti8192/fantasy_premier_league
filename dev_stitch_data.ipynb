# %%
import pandas as pd

# %%
df = pd.read_csv('data/gw1.csv')

# %%
df.head()
# Out:
#                      name position           team   xP  assists  bonus  bps  \
# 0             Femi Seriki      DEF  Sheffield Utd  0.5        0      0    0
# 1        Jack Hinshelwood      MID       Brighton  1.5        0      0    0
# 2            Jadon Sancho      MID        Man Utd  3.0        0      0    4
# 3  Rhys Norrington-Davies      DEF  Sheffield Utd  0.1        0      0    0
# 4           Vitaly Janelt      MID      Brentford  2.1        0      0    6
#
#    clean_sheets  creativity  element  ...  team_a_score  team_h_score  threat  \
# 0             0         0.0      653  ...             1             0     0.0
# 1             0         0.0      621  ...             1             4     0.0
# 2             0        11.3      397  ...             0             1     8.0
# 3             0         0.0      487  ...             1             0     0.0
# 4             0        11.5      105  ...             2             2    17.0
#
# ...

# %%
print(df.columns)
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'opponent_team',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'starts', 'team_a_score', 'team_h_score',
#        'threat', 'total_points', 'transfers_balance', 'transfers_in',
#        'transfers_out', 'value', 'was_home', 'yellow_cards'],
#       dtype='object')

# %%
for col in df:
    print(f"{col} --> {df[col].value_counts()}")
# Out:
# name --> name
# Femi Seriki            1
# Antwoine Hackford      1
# Jay Stansfield         1
# Ryan Yates             1
# Frank Onyeka           1
#                       ..
# Bryan Mbeumo           1
# Nicolas Pépé           1
# Alexis Mac Allister    1
# Omari Kellyman         1
# Mads Bech Sørensen     1
# Name: count, Length: 658, dtype: int64
# position --> position
# MID    278
# DEF    217
# FWD     87
# GK      76
# Name: count, dtype: int64
# team --> team
# Nott'm Forest     42
# Chelsea           40
# Newcastle         38
# Luton             37
# Burnley           36
# Man Utd           35
# Brighton          35
# Spurs             35
# Brentford         33
# Bournemouth       33
# Arsenal           33
# Aston Villa       32
# Everton           30
# Man City          30
# Wolves            30
# Sheffield Utd     29
# Liverpool         29
# Crystal Palace    28
# Fulham            28
# West Ham          25
# Name: count, dtype: int64
# xP --> xP
#  0.0    112
# ...

# %%
df.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'fixture', 'goals_conceded', 'goals_scored',
#        'ict_index', 'influence', 'kickoff_time', 'minutes', 'opponent_team',
#        'own_goals', 'penalties_missed', 'penalties_saved', 'red_cards',
#        'round', 'saves', 'selected', 'starts', 'team_a_score', 'team_h_score',
#        'threat', 'total_points', 'transfers_balance', 'transfers_in',
#        'transfers_out', 'value', 'was_home', 'yellow_cards'],
#       dtype='object')

# %%
df['position'].value_counts()
# Out:
# position
# MID    278
# DEF    217
# FWD     87
# GK      76
# Name: count, dtype: int64

# %%
# stitch all dfs together
df1 = pd.read_csv('data/gw1.csv')
df2 = pd.read_csv('data/gw2.csv')

# %%
cnt = df1['name'].value_counts()

# %%
cnt.max()
# Out:
# 1

# %%
df1.columns.tolist() == df2.columns.tolist()
# Out:
# True

# %%
# parse all gw data
df_list = []
for gw in range(1,39):
    df = pd.read_csv(f'data/gw{gw}.csv')
    df_list.append(df)

# %%
print(df_list)
# Out:
# [                       name position            team   xP  assists  bonus  \
# 0               Femi Seriki      DEF   Sheffield Utd  0.5        0      0
# 1          Jack Hinshelwood      MID        Brighton  1.5        0      0
# 2              Jadon Sancho      MID         Man Utd  3.0        0      0
# 3    Rhys Norrington-Davies      DEF   Sheffield Utd  0.1        0      0
# 4             Vitaly Janelt      MID       Brentford  2.1        0      0
# ..                      ...      ...             ...  ...      ...    ...
# 653             Kyle Walker      DEF        Man City  3.8        0      0
# 654             Jacob Brown      FWD           Luton  0.9        1      0
# 655          Vicente Guaita       GK  Crystal Palace  2.9        0      0
# 656  Braian Ojeda Rodríguez      MID   Nott'm Forest  0.0        0      0
# 657      Mads Bech Sørensen      DEF       Brentford  1.0        0      0
#
#      bps  clean_sheets  creativity  element  ...  team_a_score  team_h_score  \
# ...

# %%
# check if rows are in same order

# %%
# check if all columns have filled data

# %%
# check if new players show up in later game weeks, or missing in later weeks

# %%
# check if categorical data are numerical, if not numeralize it

# %%
# remove dead columns

# %%
# remove non-essential columns
